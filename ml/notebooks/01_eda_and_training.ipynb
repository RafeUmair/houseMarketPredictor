# %%
import pandas as pd

df = pd.read_csv('../data/melbourne_housing.csv')

#drop rows with missing values
df = df.dropna()

#Convert date to datetime format
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

#Convert price to float
df['Price'] = df['Price'].astype(float)

#Get year sold 
df['YearSold'] = df['Date'].dt.year

#Calculate years since sale
current_year = 2026
df['YearsSinceSale'] = current_year - df['YearSold']

#Annual Growth rate (6.5% per year)
annual_growth_rate = 0.065

#Calculate adjusted price
df['Price_Adjusted'] = df['Price'] * ((1 + annual_growth_rate) ** df['YearsSinceSale'])


df.head()
df[['Price','YearSold','YearsSinceSale','Price_Adjusted']].head(10)
# Out:
#        Suburb           Address  Rooms Type    Price       Date  Postcode  \
# 0  Abbotsford      85 Turner St      2    h  1480000 2016-12-03      3067
# 1  Abbotsford   25 Bloomburg St      2    h  1035000 2016-02-04      3067
# 2  Abbotsford      5 Charles St      3    h  1465000 2017-03-04      3067
# 3  Abbotsford  40 Federation La      3    h   850000 2017-03-04      3067
# 4  Abbotsford       55a Park St      4    h  1600000 2016-06-04      3067
#
#    Bedroom2  Bathroom  Car  Landsize  YearSold  YearsSinceSale  Price_Adjusted
# 0         2         1  1.0       202      2016              10    2.778163e+06
# 1         2         1  0.0       156      2016              10    1.942837e+06
# 2         3         2  0.0       134      2017               9    2.582166e+06
# 3         3         2  1.0        94      2017               9    1.498185e+06
# 4         3         1  2.0       120      2016              10    3.003420e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13518 entries, 0 to 13579
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Suburb          13518 non-null  object
#  1   Address         13518 non-null  object
#  2   Rooms           13518 non-null  int64
#  3   Type            13518 non-null  object
#  4   Price           13518 non-null  int64
#  5   Date            13518 non-null  datetime64[ns]
#  6   Postcode        13518 non-null  int64
#  7   Bedroom2        13518 non-null  int64
#  8   Bathroom        13518 non-null  int64
#  9   Car             13518 non-null  float64
#  10  Landsize        13518 non-null  int64
#  11  YearSold        13518 non-null  int32
#  12  YearsSinceSale  13518 non-null  int32
#  13  Price_Adjusted  13518 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int32(2), int64(6), object(3)
# memory usage: 1.4+ MB
